# %% [markdown]
# # Final Scraping Code

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd

def go_to_commentary(start_url,num,pg_num):
    '''
    function to automate mouse operations that lead from start_url to the commentary for all matches on that webpage

    '''
    df = pd.DataFrame(columns=['Date', 'Venue', 'Team_1', 'Team_2', 'Innings_no', 'Overs', 'Ball_Event', 'Comment'])

    # Iterating over alternate rows present on that webpage (matches are repeated)
    for i in range(1,num,2):
        driver = webdriver.Chrome(ChromeDriverManager().install())
        act = ActionChains(driver)
        driver.get(start_url)

        # Removing ads from the RHS of the webpage using javascript code
        ad = driver.find_element_by_id('ciHomeContentrhs')
        driver.execute_script("""
        var element = arguments[0];
        element.parentNode.removeChild(element);
        """, ad)

        block = driver.find_element_by_xpath("//*[@id='ciHomeContentlhs']/div[3]/table[3]")
        elements = block.find_elements_by_tag_name('img') # finds all images in the specified table
        # NOTE: first image is the black up arrow, use from the second element to get all the hidden menu image icons

        act.move_to_element(elements[i]).perform()
        scorecard = driver.find_element_by_link_text('Match scorecard')
        act.click(scorecard).perform()         # clicks match scorecard link
        elt = driver.find_element_by_class_name("cscore_link--button")
        status = elt.find_element_by_class_name("cscore_time")
        print(status.text)

        # Leaving out abandoned and no-result matches
        if status.text=="Result":
            stadium = driver.find_element_by_xpath \
                ("//*[@id='main-container']/div/div[3]/div[1]/div[6]/article/div/div/div[1]/h4/a/span")
            stadium = stadium.text             # getting venue details
            elt = driver.find_element_by_class_name("cscore_link--button")
            date = elt.find_element_by_class_name("cscore_info-overview")
            date_text = date.text.split(',')[2]  # getting date
            commentary = driver.find_element_by_link_text('Commentary')
            act.click(commentary).perform()        # clicks commentary link
            df_match = scrape_data(driver.current_url,stadium,date_text) # function call to scrape_data() for every match
            driver.quit()
            df = pd.concat([df, df_match])
            print("Rows in dataframe = ",df.shape[0])

        if i>=num-2:    #all matches on a single page have been covered
            print('Saving to csv file')
            file_path = '/Users/murali/code/gyandata/table'+str(pg_num)+'.csv'
            df.to_csv(file_path)


def scrape_data(url,stadium,date):
    '''
    function to visit the url passed and scrape the commentary for every ball for both the innings and return a df

    '''

    df = pd.DataFrame(columns=['Date', 'Venue', 'Team_1', 'Team_2', 'Innings_no', 'Overs', 'Ball_Event', 'Comment'])
    team_abbrev = {'South Africa': 'SA', 'Australia': 'AUS', 'Pakistan': 'PAK', 'West Indies': 'WI', 'Sri Lanka': 'SL',
                    'England':'ENG','Bangladesh':'BDESH','New Zealand':'NZ','Afghanistan':'AFG','India':'INDIA'}
    driver2 = webdriver.Chrome(ChromeDriverManager().install())
    driver2.get(url)

    # Obtaining team names
    teams = driver2.find_elements_by_class_name('cscore_name--long')
    team_names = []
    for team in teams:
        if len(team.text)!=0:
            team_names.append(team.text)
    time.sleep(2)

    #leaving out matches of teams other than those in team_abbrev dictionary
    if team_names[0] in team_abbrev.keys() and team_names[1] in team_abbrev.keys():
        # scrolling till we reach the end of the page
        driver2.maximize_window()
        elm = driver2.find_element_by_tag_name('html')
        for i in range(15):
            elm.send_keys(Keys.END)
            time.sleep(2)

        # Code to extract ball-by-ball status and commentary (first for innings 2)
        innings = 2
        wrappers = driver2.find_elements_by_class_name('item-wrapper')
        print(len(wrappers))
        for wrapper in wrappers:
            over = wrapper.find_element_by_class_name('time-stamp')
            over_value = over.text
            ball_score = wrapper.find_element_by_class_name('over-score')
            ball_event = ball_score.text
            comment = wrapper.find_element_by_class_name('description')
            comment_made = comment.text
            innings_data = [date,stadium,team_names[0],team_names[1],innings,over_value,ball_event,comment_made]
            row = pd.Series(dict(zip(df.columns,innings_data)))
            df = df.append(row,ignore_index=True)

        new_url = driver2.current_url + '?innings=1'
        driver2.get(new_url)
        driver2.maximize_window()

        # scrolling till we reach the end of the page
        elm = driver2.find_element_by_tag_name('html')
        for i in range(15):
            elm.send_keys(Keys.END)
            time.sleep(2)

        # Code to extract ball-by-ball status and commentary (now for innings 1)
        innings = 1
        wrappers = driver2.find_elements_by_class_name('item-wrapper')
        print(len(wrappers))
        for wrapper in wrappers:
            over = wrapper.find_element_by_class_name('time-stamp')
            over_value = over.text
            ball_score = wrapper.find_element_by_class_name('over-score')
            ball_event = ball_score.text
            comment = wrapper.find_element_by_class_name('description')
            comment_made = comment.text
            innings_data = [date,stadium,team_names[0],team_names[1],innings,over_value,ball_event,comment_made]
            row = pd.Series(dict(zip(df.columns,innings_data)))
            df = df.append(row,ignore_index=True)
    driver2.quit()
    print(df.head())
    return df

# %%
num_matches_per_page = 50
for page_no in range(170,172):
    start_url = 'http://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;orderby=start;page='+str(page_no)+';template=results;type=team;view=results'
    go_to_commentary(start_url,num_matches_per_page,page_no)
    print("csv file created for page ",page_no)
# Out:
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 307
# 294
#           Date                                              Venue Team_1  \
# 0   Mar 5 2019  Vidarbha Cricket Association Stadium, Jamtha, ...  India
# 1   Mar 5 2019  Vidarbha Cricket Association Stadium, Jamtha, ...  India
# 2   Mar 5 2019  Vidarbha Cricket Association Stadium, Jamtha, ...  India
# 3   Mar 5 2019  Vidarbha Cricket Association Stadium, Jamtha, ...  India
# 4   Mar 5 2019  Vidarbha Cricket Association Stadium, Jamtha, ...  India
#
#       Team_2 Innings_no Overs Ball_Event  \
# 0  Australia          2  49.3          W
# 1  Australia          2  49.2          2
# 2  Australia          2  49.1          W
# 3  Australia          2  48.6          4
# 4  Australia          2  48.5          1
#
#                                              Comment
# 0  Shankar to Zampa, OUT, in the blockhole, and i...
# 1  Shankar to Zampa, 2 runs, length ball on off s...
# 2  Shankar to Stoinis, OUT, big appeal, and it's ...
# 3  Mohammed Shami to Lyon, FOUR runs, full-toss, ...
# 4  Mohammed Shami to Stoinis, 1 run, sees Stoinis...
# Rows in dataframe =  601
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 200
# 278
#           Date                       Venue        Team_1     Team_2  \
# 0   Mar 6 2019  SuperSport Park, Centurion  South Africa  Sri Lanka
# 1   Mar 6 2019  SuperSport Park, Centurion  South Africa  Sri Lanka
# 2   Mar 6 2019  SuperSport Park, Centurion  South Africa  Sri Lanka
# 3   Mar 6 2019  SuperSport Park, Centurion  South Africa  Sri Lanka
# 4   Mar 6 2019  SuperSport Park, Centurion  South Africa  Sri Lanka
#
#   Innings_no Overs Ball_Event  \
# 0          2  32.2          W
# 1          2  32.1          1
# 2          2  31.6          1
# 3          2  31.5          0
# 4          2  31.4          0
#
#                                              Comment
# 0  Ngidi to Malinga, OUT, backs away and swats th...
# 1  Ngidi to MVT Fernando, 1 run, full and on off ...
# 2  Imran Tahir to MVT Fernando, 1 run, wraps up w...
# 3  Imran Tahir to MVT Fernando, no run, pushes it...
# 4  Imran Tahir to MVT Fernando, no run, huge swin...
# Rows in dataframe =  1079
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  1079
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 294
# 304
#           Date                                       Venue     Team_1 Team_2  \
# 0   Mar 8 2019  JSCA International Stadium Complex, Ranchi  Australia  India
# 1   Mar 8 2019  JSCA International Stadium Complex, Ranchi  Australia  India
# 2   Mar 8 2019  JSCA International Stadium Complex, Ranchi  Australia  India
# 3   Mar 8 2019  JSCA International Stadium Complex, Ranchi  Australia  India
# 4   Mar 8 2019  JSCA International Stadium Complex, Ranchi  Australia  India
#
#   Innings_no Overs Ball_Event  \
# 0          2  48.2          W
# 1          2  48.1          0
# 2          2  47.6          0
# 3          2  47.5          W
# 4          2  47.4          4
#
#                                              Comment
# 0  Cummins to Kuldeep Yadav, OUT, there's the win...
# 1  Cummins to Kuldeep Yadav, no run, back of a le...
# 2  Richardson to Bumrah, no run, full on off, and...
# 3  Richardson to Mohammed Shami, OUT, back of a l...
# 4  Richardson to Mohammed Shami, FOUR runs, lengt...
# Rows in dataframe =  1677
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  1677
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 292
# 305
#            Date                                              Venue Team_1  \
# 0   Mar 10 2019  Punjab Cricket Association IS Bindra Stadium, ...  India
# 1   Mar 10 2019  Punjab Cricket Association IS Bindra Stadium, ...  India
# 2   Mar 10 2019  Punjab Cricket Association IS Bindra Stadium, ...  India
# 3   Mar 10 2019  Punjab Cricket Association IS Bindra Stadium, ...  India
# 4   Mar 10 2019  Punjab Cricket Association IS Bindra Stadium, ...  India
#
#       Team_2 Innings_no Overs Ball_Event  \
# 0  Australia          2  47.5          2
# 1  Australia          2  47.4          W
# 2  Australia          2  47.3          1
# 3  Australia          2  47.2          1
# 4  Australia          2  47.1        4lb
#
#                                              Comment
# 0  Bumrah to Turner, 2 runs, bunts this down to t...
# 1  Bumrah to Carey, OUT, chipped and Dhawan takes...
# 2  Bumrah to Turner, 1 run, leading edge, rolls d...
# 3  Bumrah to Carey, 1 run, bunts this down to the...
# 4  Bumrah to Carey, 4 leg byes, off the pad, down...
# Rows in dataframe =  2274
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 149
# 305
#            Date              Venue        Team_1     Team_2 Innings_no Overs  \
# 0   Mar 10 2019  Kingsmead, Durban  South Africa  Sri Lanka          2  23.6
# 1   Mar 10 2019  Kingsmead, Durban  South Africa  Sri Lanka          2  23.5
# 2   Mar 10 2019  Kingsmead, Durban  South Africa  Sri Lanka          2  23.4
# 3   Mar 10 2019  Kingsmead, Durban  South Africa  Sri Lanka          2  23.3
# 4   Mar 10 2019  Kingsmead, Durban  South Africa  Sri Lanka          2  23.2
#
#   Ball_Event                                            Comment
# 0          0  Imran Tahir to Udana, no run, Oh dear and Tahi...
# 1          0  Imran Tahir to Udana, no run, full on middle s...
# 2          0  Imran Tahir to Udana, no run, googly at a leng...
# 3          1  Imran Tahir to PHKD Mendis, 1 run, length at m...
# 4          0  Imran Tahir to PHKD Mendis, no run, dropped. A...
# Rows in dataframe =  2728
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 304
# 303
#            Date                    Venue     Team_1 Team_2 Innings_no Overs  \
# 0   Mar 13 2019  Feroz Shah Kotla, Delhi  Australia  India          2  49.6
# 1   Mar 13 2019  Feroz Shah Kotla, Delhi  Australia  India          2  49.5
# 2   Mar 13 2019  Feroz Shah Kotla, Delhi  Australia  India          2  49.4
# 3   Mar 13 2019  Feroz Shah Kotla, Delhi  Australia  India          2  49.3
# 4   Mar 13 2019  Feroz Shah Kotla, Delhi  Australia  India          2  49.2
#
#   Ball_Event                                            Comment
# 0          W  Stoinis to Kuldeep Yadav, OUT, flattens the mi...
# 1          0  Stoinis to Kuldeep Yadav, no run, steps out to...
# 2          0  Stoinis to Kuldeep Yadav, no run, makes room a...
# 3          1  Stoinis to Bumrah, 1 run, banged in short, Bum...
# 4          1  Stoinis to Kuldeep Yadav, 1 run, clobbered, on...
# Rows in dataframe =  3335
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 199
# 244
#            Date                             Venue     Team_1        Team_2  \
# 0   Mar 13 2019  St George's Park, Port Elizabeth  Sri Lanka  South Africa
# 1   Mar 13 2019  St George's Park, Port Elizabeth  Sri Lanka  South Africa
# 2   Mar 13 2019  St George's Park, Port Elizabeth  Sri Lanka  South Africa
# 3   Mar 13 2019  St George's Park, Port Elizabeth  Sri Lanka  South Africa
# 4   Mar 13 2019  St George's Park, Port Elizabeth  Sri Lanka  South Africa
#
#   Innings_no Overs Ball_Event  \
# 0          2  32.5        1lb
# 1          2  32.4          1
# 2          2  32.3          0
# 3          2  32.2          1
# 4          2  32.1          4
#
#                                              Comment
# 0  NLTC Perera to Miller, 1 leg bye, doesn't make...
# 1  NLTC Perera to Duminy, 1 run, Duminy drives to...
# 2  NLTC Perera to Duminy, no run, chopped down to...
# 3  NLTC Perera to Miller, 1 run, angled down to t...
# 4  NLTC Perera to Miller, FOUR runs, Miller now s...
# Rows in dataframe =  3778
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 170
# 311
#            Date                Venue     Team_1        Team_2 Innings_no  \
# 0   Mar 16 2019  Newlands, Cape Town  Sri Lanka  South Africa          2
# 1   Mar 16 2019  Newlands, Cape Town  Sri Lanka  South Africa          2
# 2   Mar 16 2019  Newlands, Cape Town  Sri Lanka  South Africa          2
# 3   Mar 16 2019  Newlands, Cape Town  Sri Lanka  South Africa          2
# 4   Mar 16 2019  Newlands, Cape Town  Sri Lanka  South Africa          2
#
#   Overs Ball_Event                                            Comment
# 0  27.6          0  Malinga to van der Dussen, no run, bumper from...
# 1  27.5          0  Malinga to van der Dussen, no run, dug in shor...
# 2  27.4          1  Malinga to Markram, 1 run, short, and Markram ...
# 3  27.3          1  Malinga to van der Dussen, 1 run, short, and i...
# 4  27.2          1  Malinga to Markram, 1 run, slower ball, and it...
# Rows in dataframe =  4259
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 300
# 292
#            Date                    Venue    Team_1     Team_2 Innings_no  \
# 0   Mar 22 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 1   Mar 22 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 2   Mar 22 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 3   Mar 22 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 4   Mar 22 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
#
#   Overs Ball_Event                                            Comment
# 0  48.6          2  Mohammad Amir to Marsh, 2 runs, and that's the...
# 1  48.5          4  Mohammad Amir to Marsh, FOUR runs, short of a ...
# 2  48.4          1  Mohammad Amir to Handscomb, 1 run, back of a l...
# 3  48.3          1  Mohammad Amir to Marsh, 1 run, goes for the yo...
# 4  48.2          1  Mohammad Amir to Handscomb, 1 run, full outsid...
# Rows in dataframe =  4851
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 291
# 303
#            Date                    Venue    Team_1     Team_2 Innings_no  \
# 0   Mar 24 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 1   Mar 24 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 2   Mar 24 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 3   Mar 24 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
# 4   Mar 24 2019  Sharjah Cricket Stadium  Pakistan  Australia          2
#
#   Overs Ball_Event                                            Comment
# 0  47.5        2lb  Faheem Ashraf to Finch, 2 leg byes, Finch miss...
# 1  47.4          1  Faheem Ashraf to Marsh, 1 run, tip-and-run sin...
# 2  47.3          1  Faheem Ashraf to Finch, 1 run, pushed through ...
# 3  47.2          4  Faheem Ashraf to Finch, FOUR runs, 150 up for ...
# 4  47.1          6  Faheem Ashraf to Finch, SIX runs, spanked stra...
# Rows in dataframe =  5445
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 275
# 302
#            Date                            Venue     Team_1    Team_2  \
# 0   Mar 27 2019  Sheikh Zayed Stadium, Abu Dhabi  Australia  Pakistan
# 1   Mar 27 2019  Sheikh Zayed Stadium, Abu Dhabi  Australia  Pakistan
# 2   Mar 27 2019  Sheikh Zayed Stadium, Abu Dhabi  Australia  Pakistan
# 3   Mar 27 2019  Sheikh Zayed Stadium, Abu Dhabi  Australia  Pakistan
# 4   Mar 27 2019  Sheikh Zayed Stadium, Abu Dhabi  Australia  Pakistan
#
#   Innings_no Overs Ball_Event  \
# 0          2  44.4          W
# 1          2  44.3          W
# 2          2  44.2          2
# 3          2  44.1          1
# 4          2  43.6          0
#
#                                              Comment
# 0  Zampa to Mohammad Hasnain, OUT, there's a revi...
# 1  Zampa to Junaid Khan, OUT, Zampa has his third...
# 2  Zampa to Junaid Khan, 2 runs, slapped down to ...
# 3  Zampa to Yasir Shah, 1 run, legbreak, spinning...
# 4  Cummins to Junaid Khan, no run, bursting off a...
# Rows in dataframe =  6022
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 303
# 304
#            Date                                Venue     Team_1    Team_2  \
# 0   Mar 29 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 1   Mar 29 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 2   Mar 29 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 3   Mar 29 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 4   Mar 29 2019  Dubai International Cricket Stadium  Australia  Pakistan
#
#   Innings_no Overs Ball_Event  \
# 0          2  49.6          1
# 1          2  49.5          W
# 2          2  49.4          6
# 3          2  49.3          1
# 4          2  49.2          W
#
#                                              Comment
# 0  Stoinis to Yasir Shah, 1 run, another slow bou...
# 1  Stoinis to Usman Shinwari, OUT, another slog, ...
# 2  Stoinis to Usman Shinwari, SIX runs, slammed o...
# 3  Stoinis to Yasir Shah, 1 run, short, rising ov...
# 4  Stoinis to Mohammad Rizwan, OUT, caught at dee...
# Rows in dataframe =  6629
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 306
# 311
#            Date                                Venue     Team_1    Team_2  \
# 0   Mar 31 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 1   Mar 31 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 2   Mar 31 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 3   Mar 31 2019  Dubai International Cricket Stadium  Australia  Pakistan
# 4   Mar 31 2019  Dubai International Cricket Stadium  Australia  Pakistan
#
#   Innings_no Overs Ball_Event  \
# 0          2  49.6          0
# 1          2  49.5          1
# 2          2  49.4          0
# 3          2  49.3          0
# 4          2  49.3         1w
#
#                                              Comment
# 0  Richardson to Usman Shinwari, no run, and Shin...
# 1  Richardson to Imad Wasim, 1 run, Imad sets him...
# 2  Richardson to Imad Wasim, no run, on a length ...
# 3  Richardson to Imad Wasim, no run, full pace de...
# 4  Richardson to Imad Wasim, 1 wide, too short, t...
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  7246
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 132
# 305
#           Date                  Venue       Team_1      Team_2 Innings_no  \
# 0   May 7 2019  Castle Avenue, Dublin  West Indies  Bangladesh          2
# 1   May 7 2019  Castle Avenue, Dublin  West Indies  Bangladesh          2
# 2   May 7 2019  Castle Avenue, Dublin  West Indies  Bangladesh          2
# 3   May 7 2019  Castle Avenue, Dublin  West Indies  Bangladesh          2
# 4   May 7 2019  Castle Avenue, Dublin  West Indies  Bangladesh          2
#
#   Overs Ball_Event                                            Comment
# 0  44.6          4  Cottrell to Shakib Al Hasan, FOUR runs, full t...
# 1  44.5          1  Cottrell to Mushfiqur Rahim, 1 run, length bal...
# 2  44.5         1w  Cottrell to Mushfiqur Rahim, 1 wide, wide down...
# 3  44.4          6  Cottrell to Mushfiqur Rahim, SIX runs, short b...
# 4  44.3          0  Cottrell to Mushfiqur Rahim, no run, flicked t...
# Rows in dataframe =  7683
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Abandoned
# Saving to csv file
# csv file created for page  170
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# No result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Abandoned
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  0
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  0
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 309
# 310
#            Date                       Venue   Team_1    Team_2 Innings_no  \
# 0   May 11 2019  The Rose Bowl, Southampton  England  Pakistan          2
# 1   May 11 2019  The Rose Bowl, Southampton  England  Pakistan          2
# 2   May 11 2019  The Rose Bowl, Southampton  England  Pakistan          2
# 3   May 11 2019  The Rose Bowl, Southampton  England  Pakistan          2
# 4   May 11 2019  The Rose Bowl, Southampton  England  Pakistan          2
#
#   Overs Ball_Event                                            Comment
# 0  49.6          1  Woakes to Hasan Ali, 1 run, full and straight,...
# 1  49.5          0  Woakes to Hasan Ali, no run, pitched up, right...
# 2  49.4          1  Woakes to Sarfaraz Ahmed, 1 run, pitched up an...
# 3  49.3          0  Woakes to Sarfaraz Ahmed, no run, another wide...
# 4  49.2          1  Woakes to Hasan Ali, 1 run, full, 84mph and sq...
# Rows in dataframe =  619
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 290
# 303
#            Date                          Venue       Team_1      Team_2  \
# 0   May 13 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 1   May 13 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 2   May 13 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 3   May 13 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 4   May 13 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
#
#   Innings_no Overs Ball_Event  \
# 0          2  47.3         1w
# 1          2  47.2          1
# 2          2  47.1          2
# 3          2  46.6          1
# 4          2  46.5          0
#
#                                              Comment
# 0  Cottrell to Sabbir Rahman, 1 wide, bouncer dow...
# 1  Cottrell to Mahmudullah, 1 run, full on off st...
# 2  Cottrell to Mahmudullah, 2 runs, overpitched, ...
# 3  Roach to Mahmudullah, 1 run, full on middle st...
# 4  Roach to Mahmudullah, no run, fullish, angling...
# Rows in dataframe =  1212
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 278
# 309
#            Date                   Venue    Team_1   Team_2 Innings_no Overs  \
# 0   May 14 2019  County Ground, Bristol  Pakistan  England          2  44.5
# 1   May 14 2019  County Ground, Bristol  Pakistan  England          2  44.4
# 2   May 14 2019  County Ground, Bristol  Pakistan  England          2  44.3
# 3   May 14 2019  County Ground, Bristol  Pakistan  England          2  44.2
# 4   May 14 2019  County Ground, Bristol  Pakistan  England          2  44.1
#
#   Ball_Event                                            Comment
# 0          1  Asif Ali to Morgan, 1 run, pushed into the cov...
# 1          1  Asif Ali to Ali, 1 run, hoicked to the leg sid...
# 2          1  Asif Ali to Morgan, 1 run, pushed calmly down ...
# 3          4  Asif Ali to Morgan, FOUR runs, outside off, an...
# 4          2  Asif Ali to Morgan, 2 runs, smashed firmly dow...
# Rows in dataframe =  1799
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  1799
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 142
# 148
#            Date                          Venue       Team_1      Team_2  \
# 0   May 17 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 1   May 17 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 2   May 17 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 3   May 17 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
# 4   May 17 2019  The Village, Malahide, Dublin  West Indies  Bangladesh
#
#   Innings_no Overs Ball_Event  \
# 0          2  22.5          4
# 1          2  22.4          0
# 2          2  22.3          1
# 3          2  22.2          0
# 4          2  22.1          0
#
#                                              Comment
# 0  Reifer to Mahmudullah, FOUR runs, Bangladesh w...
# 1  Reifer to Mahmudullah, no run, length ball, on...
# 2  Reifer to Mosaddek Hossain, 1 run, slower ball...
# 3  Reifer to Mosaddek Hossain, no run, length bal...
# 4  Reifer to Mosaddek Hossain, no run, full, just...
# Rows in dataframe =  2089
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 305
# 307
#            Date                     Venue    Team_1   Team_2 Innings_no Overs  \
# 0   May 17 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.3
# 1   May 17 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.2
# 2   May 17 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.1
# 3   May 17 2019  Trent Bridge, Nottingham  Pakistan  England          2  48.6
# 4   May 17 2019  Trent Bridge, Nottingham  Pakistan  England          2  48.5
#
#   Ball_Event                                            Comment
# 0          1  Hasan Ali to Stokes, 1 run, dug in short, Stok...
# 1          1  Hasan Ali to Rashid, 1 run, angling in at 85mp...
# 2          1  Hasan Ali to Stokes, 1 run, pitched up outside...
# 3          4  Junaid Khan to Rashid, FOUR runs, full, 85mph ...
# 4          2  Junaid Khan to Rashid, 2 runs, appeal for lbw ...
# Rows in dataframe =  2701
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Abandoned
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  2701
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 284
# 306
#            Date              Venue   Team_1    Team_2 Innings_no Overs  \
# 0   May 19 2019  Headingley, Leeds  England  Pakistan          2  46.5
# 1   May 19 2019  Headingley, Leeds  England  Pakistan          2  46.4
# 2   May 19 2019  Headingley, Leeds  England  Pakistan          2  46.3
# 3   May 19 2019  Headingley, Leeds  England  Pakistan          2  46.2
# 4   May 19 2019  Headingley, Leeds  England  Pakistan          2  46.1
#
#   Ball_Event                                            Comment
# 0          W  Rashid to Mohammad Hasnain, OUT, flight and sp...
# 1          0  Rashid to Mohammad Hasnain, no run, pushed thr...
# 2          4  Rashid to Mohammad Hasnain, FOUR runs, makes a...
# 3          1  Rashid to Shaheen Shah Afridi, 1 run, floated ...
# 4          0  Rashid to Shaheen Shah Afridi, no run, tossed ...
# Rows in dataframe =  3291
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  3291
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Empty DataFrame
# Columns: [Date, Venue, Team_1, Team_2, Innings_no, Overs, Ball_Event, Comment]
# Index: []
# Rows in dataframe =  3291
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 240
# 308
#            Date                    Venue   Team_1        Team_2 Innings_no  \
# 0   May 30 2019  Kennington Oval, London  England  South Africa          2
# 1   May 30 2019  Kennington Oval, London  England  South Africa          2
# 2   May 30 2019  Kennington Oval, London  England  South Africa          2
# 3   May 30 2019  Kennington Oval, London  England  South Africa          2
# 4   May 30 2019  Kennington Oval, London  England  South Africa          2
#
#   Overs Ball_Event                                            Comment
# 0  39.5          W  Stokes to Imran Tahir, OUT, edged, gone, Stoke...
# 1  39.4          W  Stokes to Rabada, OUT, short again, pulled aga...
# 2  39.3        4lb  Stokes to Rabada, 4 leg byes, on the hip, ping...
# 3  39.2          0  Stokes to Rabada, no run, short, slapped, inch...
# 4  39.1          4  Stokes to Rabada, FOUR runs, canny deflection,...
# Rows in dataframe =  3839
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 85
# 134
#            Date                     Venue    Team_1       Team_2 Innings_no  \
# 0   May 31 2019  Trent Bridge, Nottingham  Pakistan  West Indies          2
# 1   May 31 2019  Trent Bridge, Nottingham  Pakistan  West Indies          2
# 2   May 31 2019  Trent Bridge, Nottingham  Pakistan  West Indies          2
# 3   May 31 2019  Trent Bridge, Nottingham  Pakistan  West Indies          2
# 4   May 31 2019  Trent Bridge, Nottingham  Pakistan  West Indies          2
#
#   Overs Ball_Event                                            Comment
# 0  13.4          6  Wahab Riaz to Pooran, SIX runs, that's the end...
# 1  13.3          0  Wahab Riaz to Pooran, no run, beaten as he's w...
# 2  13.2          4  Wahab Riaz to Pooran, FOUR runs, backs away to...
# 3  13.1          1  Wahab Riaz to Hetmyer, 1 run, looks to back aw...
# 4  13.1         1w  Wahab Riaz to Hetmyer, 1 wide, shapes to pull ...
# Rows in dataframe =  4058
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 100
# 186
#           Date                    Venue     Team_1       Team_2 Innings_no  \
# 0   Jun 1 2019  Sophia Gardens, Cardiff  Sri Lanka  New Zealand          2
# 1   Jun 1 2019  Sophia Gardens, Cardiff  Sri Lanka  New Zealand          2
# 2   Jun 1 2019  Sophia Gardens, Cardiff  Sri Lanka  New Zealand          2
# 3   Jun 1 2019  Sophia Gardens, Cardiff  Sri Lanka  New Zealand          2
# 4   Jun 1 2019  Sophia Gardens, Cardiff  Sri Lanka  New Zealand          2
#
#   Overs Ball_Event                                            Comment
# 0  16.1          1  BMAJ Mendis to Munro, 1 run, gentle nudge behi...
# 1  15.6          2  Malinga to Guptill, 2 runs, tucks this full to...
# 2  15.5          0  Malinga to Guptill, no run, squeezes this york...
# 3  15.5        5nb  Malinga to Guptill, (no ball) FOUR runs, overs...
# 4  15.4          4  Malinga to Guptill, FOUR runs, pulled so well ...
# Rows in dataframe =  4344
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 217
# 239
#           Date                   Venue       Team_1     Team_2 Innings_no  \
# 0   Jun 1 2019  County Ground, Bristol  Afghanistan  Australia          2
# 1   Jun 1 2019  County Ground, Bristol  Afghanistan  Australia          2
# 2   Jun 1 2019  County Ground, Bristol  Afghanistan  Australia          2
# 3   Jun 1 2019  County Ground, Bristol  Afghanistan  Australia          2
# 4   Jun 1 2019  County Ground, Bristol  Afghanistan  Australia          2
#
#   Overs Ball_Event                                            Comment
# 0  34.5          4  Mujeeb Ur Rahman to Maxwell, FOUR runs, well m...
# 1  34.4          W  Mujeeb Ur Rahman to Smith, OUT, anti-climax wi...
# 2  34.3          0  Mujeeb Ur Rahman to Smith, no run, fuller outs...
# 3  34.2          1  Mujeeb Ur Rahman to Warner, 1 run, quicker and...
# 4  34.1          0  Mujeeb Ur Rahman to Warner, no run, fuller, dr...
# Rows in dataframe =  4800
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 306
# 308
#           Date                    Venue      Team_1        Team_2 Innings_no  \
# 0   Jun 2 2019  Kennington Oval, London  Bangladesh  South Africa          2
# 1   Jun 2 2019  Kennington Oval, London  Bangladesh  South Africa          2
# 2   Jun 2 2019  Kennington Oval, London  Bangladesh  South Africa          2
# 3   Jun 2 2019  Kennington Oval, London  Bangladesh  South Africa          2
# 4   Jun 2 2019  Kennington Oval, London  Bangladesh  South Africa          2
#
#   Overs Ball_Event                                            Comment
# 0  49.6          2  Mustafizur Rahman to Imran Tahir, 2 runs, sque...
# 1  49.5          2  Mustafizur Rahman to Imran Tahir, 2 runs, slic...
# 2  49.4          0  Mustafizur Rahman to Imran Tahir, no run, beat...
# 3  49.3          1  Mustafizur Rahman to Rabada, 1 run, hits it hi...
# 4  49.2          0  Mustafizur Rahman to Rabada, no run, squeezes ...
# Rows in dataframe =  5414
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 305
# 309
#           Date                     Venue    Team_1   Team_2 Innings_no Overs  \
# 0   Jun 3 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.6
# 1   Jun 3 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.5
# 2   Jun 3 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.4
# 3   Jun 3 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.3
# 4   Jun 3 2019  Trent Bridge, Nottingham  Pakistan  England          2  49.2
#
#   Ball_Event                                            Comment
# 0          4  Wahab Riaz to Wood, FOUR runs, Wahab bowls off...
# 1          1  Wahab Riaz to Rashid, 1 run, slower bouncer on...
# 2          1  Wahab Riaz to Wood, 1 run, very full and angli...
# 3          0  Wahab Riaz to Wood, no run, Wood gives himself...
# 4          4  Wahab Riaz to Wood, FOUR runs, Wood backs away...
# Rows in dataframe =  6028
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 208
# 234
#           Date                    Venue     Team_1       Team_2 Innings_no  \
# 0   Jun 4 2019  Sophia Gardens, Cardiff  Sri Lanka  Afghanistan          2
# 1   Jun 4 2019  Sophia Gardens, Cardiff  Sri Lanka  Afghanistan          2
# 2   Jun 4 2019  Sophia Gardens, Cardiff  Sri Lanka  Afghanistan          2
# 3   Jun 4 2019  Sophia Gardens, Cardiff  Sri Lanka  Afghanistan          2
# 4   Jun 4 2019  Sophia Gardens, Cardiff  Sri Lanka  Afghanistan          2
#
#   Overs Ball_Event                                            Comment
# 0  32.4          W  Malinga to Hamid Hassan, OUT, excellent comeba...
# 1  32.3          6  Malinga to Hamid Hassan, SIX runs, slower ball...
# 2  32.2          0                   Malinga to Hamid Hassan, no run,
# 3  32.1          1  Malinga to Mujeeb Ur Rahman, 1 run, yorker, ta...
# 4  31.6          W  Udana to Najibullah Zadran, OUT, full on off, ...
# Rows in dataframe =  6470
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 289
# 306
#           Date                       Venue        Team_1 Team_2 Innings_no  \
# 0   Jun 5 2019  The Rose Bowl, Southampton  South Africa  India          2
# 1   Jun 5 2019  The Rose Bowl, Southampton  South Africa  India          2
# 2   Jun 5 2019  The Rose Bowl, Southampton  South Africa  India          2
# 3   Jun 5 2019  The Rose Bowl, Southampton  South Africa  India          2
# 4   Jun 5 2019  The Rose Bowl, Southampton  South Africa  India          2
#
#   Overs Ball_Event                                            Comment
# 0  47.3          4  Phehlukwayo to Pandya, FOUR runs, he's carved ...
# 1  47.3         1w  Phehlukwayo to Pandya, 1 wide, another steep b...
# 2  47.2          0  Phehlukwayo to Pandya, no run, skiddy bouncer,...
# 3  47.1          2  Phehlukwayo to Pandya, 2 runs, flayed on the u...
# 4  46.6          1  Morris to Pandya, 1 run, punched to deep point...
# Rows in dataframe =  7065
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 293
# 305
#           Date                    Venue      Team_1       Team_2 Innings_no  \
# 0   Jun 5 2019  Kennington Oval, London  Bangladesh  New Zealand          2
# 1   Jun 5 2019  Kennington Oval, London  Bangladesh  New Zealand          2
# 2   Jun 5 2019  Kennington Oval, London  Bangladesh  New Zealand          2
# 3   Jun 5 2019  Kennington Oval, London  Bangladesh  New Zealand          2
# 4   Jun 5 2019  Kennington Oval, London  Bangladesh  New Zealand          2
#
#   Overs Ball_Event                                            Comment
# 0  47.1          4  Mustafizur Rahman to Santner, FOUR runs, full ...
# 1  46.6          4  Mohammad Saifuddin to Ferguson, FOUR runs, tha...
# 2  46.6         1w  Mohammad Saifuddin to Ferguson, 1 wide, better...
# 3  46.6         1w  Mohammad Saifuddin to Ferguson, 1 wide, short ...
# 4  46.5          0  Mohammad Saifuddin to Ferguson, no run, length...
# Rows in dataframe =  7663
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# Result
#
# Checking for mac64 chromedriver:75.0.3770.90 in cache
# Driver found in /Users/murali/.wdm/chromedriver/75.0.3770.90/mac64/chromedriver
# 307
# 315
#           Date                     Venue     Team_1       Team_2 Innings_no  \
# 0   Jun 6 2019  Trent Bridge, Nottingham  Australia  West Indies          2
# 1   Jun 6 2019  Trent Bridge, Nottingham  Australia  West Indies          2
# 2   Jun 6 2019  Trent Bridge, Nottingham  Australia  West Indies          2
# 3   Jun 6 2019  Trent Bridge, Nottingham  Australia  West Indies          2
# 4   Jun 6 2019  Trent Bridge, Nottingham  Australia  West Indies          2
#
#   Overs Ball_Event                                            Comment
# 0  49.6          4  Coulter-Nile to Nurse, FOUR runs, another firm...
# 1  49.5          4  Coulter-Nile to Nurse, FOUR runs, another shor...
# 2  49.4          4  Coulter-Nile to Nurse, FOUR runs, full otuside...
# 3  49.3          4  Coulter-Nile to Nurse, FOUR runs, short on the...
# 4  49.2          0  Coulter-Nile to Nurse, no run, short on the bo...
# Rows in dataframe =  8285
# Saving to csv file
# csv file created for page  171
